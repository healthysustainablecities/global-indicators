# %%
import json
import os
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import osmnx as ox
import random
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Load and Clean Data

# %%
process_folder = '../../process'
process_config_path = '../../process/configuration/adelaide.json'
pop_col = ["pop_ghs_2015"]
dest_col = ["destinations"]
filenames_filepath = "./filenames.csv"
np.random.seed(24)

# %%
with open(process_config_path) as json_file:
    config = json.load(json_file)

input_folder = os.path.join(process_folder, config['folder'])

gpkg_input = os.path.join(input_folder, config['geopackagePath'])

# %%
pop = gpd.read_file(gpkg_input, layer='pop_ghs_2015' )

# %%
dests = gpd.read_file(gpkg_input, layer='destinations' )

# %%
fresh_food = dests[dests['dest_name_full'].str.contains('Fresh Food / Market')]

# %%
gdf_study_area = gpd.read_file(gpkg_input, layer="urban_study_region")
study_area = gdf_study_area["geometry"].iloc[0]

# %%
crs = gdf_study_area.crs
if pop.crs != crs:
    pop = pop.to_crs(crs)
if fresh_food.crs != crs:
    fresh_food = fresh_food.to_crs(crs)

# %%
import warnings

warnings.filterwarnings("ignore", "GeoSeries.notna", UserWarning)  # temp warning suppression
pop_clipped = gpd.clip(pop, study_area)
fresh_food_clipped = gpd.clip(fresh_food, study_area)

# %% [markdown]
# ## Assign Hexagon-Data to Destinations

# %%
joined_freshfood = gpd.sjoin(fresh_food_clipped, pop_clipped, how='left', op='within')

# %% [markdown]
# ## Create Density-Based Quintiles

# %%
ordered_joined_freshfood = joined_freshfood.sort_values('pop_est')

# %%
split_joined_freshfood = np.array_split(ordered_joined_freshfood, 5)

# %%
q1_dests = (split_joined_freshfood[0])
q2_dests = (split_joined_freshfood[1])
q3_dests = (split_joined_freshfood[2])
q4_dests = (split_joined_freshfood[3])
q5_dests = (split_joined_freshfood[4])

# %%
q1_dests['quantile'] = 1
q2_dests['quantile'] = 2
q3_dests['quantile'] = 3
q4_dests['quantile'] = 4
q5_dests['quantile'] = 5

# %% [markdown]
# ## Select Destinations

# %%
q1_sample_dests = q1_dests.sample(10)
q2_sample_dests = q2_dests.sample(10)
q3_sample_dests = q3_dests.sample(10)
q4_sample_dests = q4_dests.sample(10)
q5_sample_dests = q5_dests.sample(10)

# %%
sample_dests = [q1_sample_dests, q2_sample_dests, q3_sample_dests, q4_sample_dests, q5_sample_dests]

# %%
final_sample_dests = pd.concat(sample_dests)

# %%
final_sample_dests = final_sample_dests.to_crs({'init': 'epsg:4326'})
# Out:
# /opt/conda/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
final_sample_dests['lat'] = final_sample_dests.geometry.y
final_sample_dests['lon'] = final_sample_dests.geometry.x

# %%
final_sample_dests = final_sample_dests.set_index('osm_id')

# %%
final_sample_dests
# Out:
#             dest_oid          dest_name       dest_name_full  edge_ogc_fid  \
# osm_id
# 554005639        387  fresh_food_market  Fresh Food / Market        117664
# 4836645274       305  fresh_food_market  Fresh Food / Market        230128
# 2424960625       350  fresh_food_market  Fresh Food / Market        116821
# 5330994352        66  fresh_food_market  Fresh Food / Market        133298
# 2029087875        71  fresh_food_market  Fresh Food / Market        124730
# 5344476192        18  fresh_food_market  Fresh Food / Market         18952
# 4835897220        34  fresh_food_market  Fresh Food / Market        191114
# 5279252487                    39  POINT (138.67278 -34.82904)  ...
# 848338230                     29  POINT (138.60160 -34.87499)  ...
# 447248196                     19  POINT (138.50306 -34.88106)  ...
# 820424383                     39  POINT (138.70071 -34.87138)  ...
# 4405228845                    11  POINT (138.59501 -34.90716)  ...
# 280726477                      5  POINT (138.61477 -34.95677)  ...
# 2391427400                    20  POINT (138.53066 -34.90422)  ...
# 5121171286                    11  POINT (138.56537 -34.89668)  ...
# 2311759501                    43  POINT (138.51425 -34.91403)  ...
# 2382205204                    16  POINT (138.51962 -34.85885)  ...
# 479978814                     13  POINT (138.65049 -34.91447)  ...
# 4438466555                    18  POINT (138.48282 -34.83864)  ...
# 1868639259                    14  POINT (138.58966 -34.95183)  ...
# 215062216                     32  POINT (138.56850 -34.89417)  ...
# 5842960944                    18  POINT (138.56558 -34.99323)  ...
# 2285373485                    13  POINT (138.57255 -34.89012)  ...
# 2534586738                    17  POINT (138.51440 -34.91948)  ...
# 6839233326                    12  POINT (138.63166 -34.93548)  ...
# 2980575418                    15  POINT (138.65033 -34.92701)  ...
# 93730429                      10  POINT (138.56187 -34.92451)  ...
# 1475563597                    31  POINT (138.70649 -34.77100)  ...
# 6649086885                    16  POINT (138.63196 -34.91521)  ...
# 1252175664                    11  POINT (138.48386 -34.83877)  ...
# 314933815                     26  POINT (138.65036 -34.92742)  ...
#
#             count_restaurant  count_convenience  count_bar  count_fast_food  \
# osm_id
# 554005639                NaN                NaN        NaN              NaN
# 4836645274               NaN                NaN        NaN              NaN
# 2424960625               NaN                1.0        NaN              1.0
# 5330994352               NaN                NaN        NaN              NaN
# 2029087875               NaN                NaN        NaN              NaN
# 5344476192               NaN                NaN        NaN              NaN
# 4835897220               NaN                NaN        NaN              NaN
# 4504321790               NaN                NaN        NaN              NaN
# 653722296                NaN                NaN        NaN              NaN
# 5411249887               NaN                NaN        NaN              NaN
# 5062044427               NaN                NaN        NaN              2.0
# 2396009490               1.0                NaN        NaN              4.0
# 6251187686               1.0                2.0        NaN              1.0
# 451871161                1.0                NaN        NaN              4.0
# 581224379                2.0                NaN        NaN              1.0
# 4449963307               NaN                NaN        NaN              2.0
# 3475954745               NaN                1.0        NaN              1.0
# 7628155095               NaN                NaN        NaN              NaN
# 4504307296               NaN                NaN        NaN              NaN
# 247052429                2.0                NaN        NaN              1.0
# 6917370085               NaN                NaN        NaN              NaN
# 187373304                NaN                1.0        NaN              4.0
# 854633067                NaN                NaN        NaN              NaN
# 5279252491               NaN                1.0        NaN              1.0
# 5276627283               NaN                1.0        NaN              1.0
# 6109038000               2.0                NaN        NaN              NaN
# 5279252487               NaN                1.0        NaN              1.0
# 848338230                NaN                NaN        NaN              NaN
# 447248196                NaN                NaN        NaN              NaN
# 820424383                NaN                1.0        NaN              NaN
# 4405228845               5.0                1.0        NaN              NaN
# 280726477                NaN                NaN        NaN              NaN
# 2391427400               NaN                1.0        NaN              1.0
# 5121171286               NaN                NaN        NaN              NaN
# 2311759501               NaN                NaN        NaN              1.0
# 2382205204               NaN                NaN        NaN              2.0
# 479978814                1.0                NaN        NaN              1.0
# 4835897220 -34.880764  138.490802
# 4504321790 -34.830226  138.691505
# 653722296  -34.935031  138.523309
# 5411249887 -35.089796  138.540536
# 5062044427 -34.924612  138.675871
# 2396009490 -34.873992  138.549416
# 6251187686 -34.925542  138.663308
# 451871161  -34.874121  138.548876
# 581224379  -35.015950  138.522126
# 4449963307 -34.869556  138.529344
# 3475954745 -35.083635  138.561485
# 7628155095 -34.915732  138.628209
# 4504307296 -34.815610  138.699521
# 247052429  -34.896675  138.556830
# 6917370085 -34.905012  138.656163
# 187373304  -34.851805  138.527405
# 854633067  -34.821090  138.718039
# 5279252491 -34.829026  138.673025
# 5276627283 -34.829564  138.672182
# 6109038000 -34.912770  138.673817
# 5279252487 -34.829043  138.672777
# 848338230  -34.874987  138.601597
# 447248196  -34.881059  138.503060
# 820424383  -34.871376  138.700707
# 4405228845 -34.907155  138.595010
# 280726477  -34.956775  138.614774
# 2391427400 -34.904221  138.530660
# 5121171286 -34.896684  138.565369
# 2311759501 -34.914027  138.514247
# 2382205204 -34.858852  138.519622
# 479978814  -34.914469  138.650490
# 4438466555 -34.838636  138.482822
# 1868639259 -34.951826  138.589664
# 215062216  -34.894173  138.568502
# 5842960944 -34.993231  138.565583
# 2285373485 -34.890122  138.572552
# 2534586738 -34.919480  138.514404
# 6839233326 -34.935479  138.631655
# 2980575418 -34.927014  138.650329
# 93730429   -34.924508  138.561866
# 1475563597 -34.771004  138.706486
# 6649086885 -34.915215  138.631964
# 1252175664 -34.838766  138.483860
# 314933815  -34.927421  138.650361
#
# [50 rows x 29 columns]

# %%
cities = ['adelaide']
filenames = {}

for city in cities: 
    for index, row in final_sample_dests.iterrows():
        city_name = city
        hexagon_pop_quantile = row['quantile']
        latitude = row['lat']
        longitude = row['lon']
        google_maps_screenshot = f"{latitude}_{longitude}_{city}_google_maps_image"
        google_satellite_screenshot = f"{latitude}_{longitude}_{city}_google_satellite_image"
        google_street_view_screenshot = f"{latitude}_{longitude}_{city}_google_street_view_image"

        # calculate total street length and edge count in each dataset, then add to indicators
        filenames[index] = {}
        filenames[index]["Hexagon_Pop_Quintile"] = hexagon_pop_quantile
        filenames[index]["City_Name"] = city_name
        filenames[index]["Latitude"] = latitude
        filenames[index]["Longitude"] = longitude
        filenames[index]["Google_Maps_Date"] = ""
        filenames[index]["Google_Maps_Screenshot"] = google_maps_screenshot
        filenames[index]["Google_Satellite_Date"] = ""
        filenames[index]["Google_Satellite_Screenshot"] = google_satellite_screenshot
        filenames[index]["Google_Street_View_Date"] = ""
        filenames[index]["Google_Street_View_Screenshot"] = google_street_view_screenshot
        filenames[index]["Assessment"] = ""
        filenames[index]["Comments"] = ""

print(ox.ts(), f"finshed names for {city}")

# turn indicators into a dataframe and save to disk
df_filenames = pd.DataFrame(filenames).T
df_filenames.to_csv(filenames_filepath, index=True, encoding="utf-8")
print(ox.ts(), f'all done, saved filenames to disk at "{filenames_filepath}"')
# Out:
# 2020-11-01 18:57:03 finshed names for adelaide
# 2020-11-01 18:57:03 all done, saved filenames to disk at "./filenames.csv"
